# %% [markdown]
# # Optical Signal Quality Prediction
#
#
#
# ![image.png](attachment:1e8e055a-ebbb-4bb0-948d-742a95aeef2b.png)
#
#
# ![image.png](attachment:7b2bcb78-d438-4909-bbab-ac6c7d1f00bb.png)
#
#
# Optical fiber is a fantastic medium for propagating light signals, and it rarely needs amplification in contrast to copper cables. High-quality single mode fiber will often exhibit attenuation (loss of power) as low as 0.1dB per kilometer.

# %% [markdown]
# ## Tasks Measure of the overall quality of the optical signal

# %% [markdown]
# **About Dataset**
# Data Collection Method:
# The data was collected using a combination of laboratory experiments and field measurements in real-world optical communication networks. Various instruments such as optical power meters, spectrum analyzers, and BER testers were utilized to capture relevant parameters
# **.
# Feature Names and Descriptio**n- s:
# Transmit Power Level (T):
#
# Description: The power level at which the signal is transmitted into the optical
#
# - iber.
# Receive Power Level(Rx):
#
# Description: The power level of the received signal after propagation through the optic
# a-l fiber.
# Power Level at Various Points (VariousPoints):
#
# Description: Power levels measured at different points along the op
# t- ical fiber.
# Signal-to-Noise Ratio (SNR) at Receiver (SN Receiver):
#
# Description: The ratio of signal power to noise power a
# t-  the receiver.
# SNR at Different Stages of Signal Processin (SNR Stages):
#
# Description: Signal-to-noise ratio measured at various stages of
# s- ignal processing.
# Bit Error Rate (BER) at Receivr (BER Receiver):
#
# Description: The rate at which bits are received in e
# r- ror at the receiver.
# BER Under Different Environmental Conditions(BER Environmental):
#
# Description: Bit error rate measured under different e
# n- vironmental conditions.
# Modulation Forat (Modulation Format):
#
# Description: The format used for mod
# u- lating the optical signal.
# Modulation Depth o Index (Modulation Depth):
#
# Description: The depth or index of modulation
# applied to the optical signal.
# Transmission Disance (Transmission Distance):
#
# Description: The distance over which t
# h- e optical signal is transmitted.
# Distance Between Repeaters r Amplifiers (Distance Between):
#
# Description: The distance between repeaters or
#  - amplifiers along the optical fiber.
# Fiber Attenuatin Coefficients (Fiber Attenuation):
#
# Description: Coefficients representing the attenuat
# i- on of the optical signal in the fiber.
# Splice Losss or Connector Losses (Splice Losses):
#
# Description: Losses incurred at spl
# i- ces or connectors along the optical path.
# Gain of Opical Amplifiers (Optical Amplifier Gain):
#
# Description: The gain provided by opti
# c- al amplifiers to amplify the optical signal.
# Polarization Mode Dipersion (PMD) Coefficient (PMD Coefficient):
#
# Description: Coefficient representing the leve
# l-  of polarization mode dispersion in the system.
# PMD Compensation Techniques (PMD Compensation):
#
# Description: Techniques emplo
# y- ed to compensate for polarization mode dispersion.
# Chroatic Dispersion (CD) Coefficient (CD Coefficient):
#
# Description: Coefficient represe
# n- ting the level of chromatic dispersion in the ystem.
# CD Compensation Techniques (CD Compensation):
#
# Description: Te
# c- hniques employed to compensate for chromatic dspersion.
# Temperature at Critical Points (Temperature):
#
# Description: Temperature measurem
# ents at critical points in th optical communication system.
# Humidity Levels (Humidity):
#
# Description: Levels of humidity
#  - affecting the performance of the optical commuication system.
# Wavelength Drift or Shift (Wavelength Drift):
#
# De
# s- cription: Drift or shift in the wavelength of the optica signal.
# Stability of Optical Source (Optical Source Stability):
#
# Description
# :-  Stability characteristics of the opticl source used in the system.
# Nonlinear Effects (Nonlinear Effects):
#
# Description
# : Effects of nonlinearities in the optical component on signal quality.
# Equalization Techniques (Equalization Techniques):
#
# Description: Tec
# h- niques employed for equalizing the optical signal to mitigate distortons.
# Digital Signal Processing Algorithms (Signal Processing Algorithms):
#
# Description: Algo
# r- ithms used for digital signal processing in the optical communication sytem.
# Optical Crosstalk from Adjacent Channels or Fibers (Optical Crosstalk):
#
# De
# s- cription: Crosstalk from adjacent channels or fibers affcting signal integrity.
# Crosstalk Mitigation Techniques (Crosstalk Mitigatio
# n- ):
#
# Description: Techniques employed to mitigate optical crsstalk in the system.
# Level of Data Traffic in the Network (Network Traffic Load):
#
# -
# Description: The level of data traffi present in the optical communication network.
# Congestion Levels (Congestion Leve.
# s- ):
#
# Description: Levels of congestion experienced in the optical communiation network.
# Presence of Security Threats Affecting Signal Quality (Security Threats):
#
# -
# Description: Identification of security threats impacting signal integrityin the network.
# Impact of Security Measures on Signal Integrity (Security Menal Quality (Signal Quality):
#
# Description: Measure of the overall quality of the optical signal.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
data = pd.read_csv('Optical Signal Prediction.csv')

# %%
data.head()
# Out:
#      Tx    Rx  Various Points  SNR Receiver  SNR Stages  BER Receiver  \
# 0  10.5  15.2            12.8          23.6        22.1      0.000001
# 1  11.2  16.5            12.6          24.2        22.8      0.000001
# 2   9.8  14.8            12.9          23.4        21.9      0.000001
# 3  12.1  18.2            13.2          24.8        23.5      0.000002
# 4  10.9  15.8            13.0          24.0        22.5      0.000001
#
#    BER Environmental Modulation Format  Modulation Depth  \
# 0           0.000002                AM               0.8
# 1           0.000002                FM               0.7
# 2           0.000001                PM               0.9
# 3           0.000002                AM               0.8
# 4           0.000002                FM               0.7
#
#    Transmission Distance  ...  Fiber Attenuation  Splice Losses  \
# 0                     20  ...               0.10           0.20
# 1                     21  ...               0.11           0.22
# ...

# %%
data.tail(3)
# Out:
#        Tx    Rx  Various Points  SNR Receiver  SNR Stages  BER Receiver  \
# 583  12.9  19.3            13.8          25.5        24.0  1.900000e-06
# 584   9.3  14.0            12.5          22.8        21.3  8.000000e-07
# 585  12.4  18.6            13.4          24.9        23.3  1.500000e-06
#
#      BER Environmental Modulation Format  Modulation Depth  \
# 583           0.000002                AM               0.8
# 584           0.000001                AM               0.8
# 585           0.000002                AM               0.8
#
#      Transmission Distance  ...  Fiber Attenuation  Splice Losses  \
# 583                     23  ...               0.13           0.26
# 584                     17  ...               0.07           0.14
# 585                     21  ...               0.11           0.22
#
#      Optical Amplifier Gain  PMD Coefficient  PMD Compensation CD Coefficient  \
# 583                      13             0.08   PMD Compensated          0.060
# ...

# %%
data.columns
# Out:
# Index(['Tx', 'Rx', 'Various Points', 'SNR Receiver', 'SNR Stages',
#        'BER Receiver', 'BER Environmental', 'Modulation Format',
#        'Modulation Depth', 'Transmission Distance', 'Distance Between',
#        'Fiber Attenuation', 'Splice Losses', 'Optical Amplifier Gain',
#        'PMD Coefficient', 'PMD Compensation', 'CD Coefficient',
#        'CD Compensation', 'Temperature', 'Humidity', 'Signal Quality'],
#       dtype='object')

# %%
data.shape[0]
# Out:
# 586

# %%
data.shape[1]
# Out:
# 21

# %%
data.shape
# Out:
# (586, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586 entries, 0 to 585
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Tx                      586 non-null    float64
#  1   Rx                      586 non-null    float64
#  2   Various Points          586 non-null    float64
#  3   SNR Receiver            586 non-null    float64
#  4   SNR Stages              586 non-null    float64
#  5   BER Receiver            586 non-null    float64
#  6   BER Environmental       586 non-null    float64
#  7   Modulation Format       586 non-null    object
#  8   Modulation Depth        586 non-null    float64
#  9   Transmission Distance   586 non-null    int64
#  10  Distance Between        586 non-null    int64
#  11  Fiber Attenuation       586 non-null    float64
#  12  Splice Losses           586 non-null    float64
#  13  Optical Amplifier Gain  586 non-null    int64
# ...

# %%
data.isnull().sum()
# Out:
# Tx                        0
# Rx                        0
# Various Points            0
# SNR Receiver              0
# SNR Stages                0
# BER Receiver              0
# BER Environmental         0
# Modulation Format         0
# Modulation Depth          0
# Transmission Distance     0
# Distance Between          0
# Fiber Attenuation         0
# Splice Losses             0
# Optical Amplifier Gain    0
# PMD Coefficient           0
# PMD Compensation          0
# CD Coefficient            0
# CD Compensation           0
# Temperature               1
# Humidity                  1
# Signal Quality            1
# dtype: int64

# %%
plt.figure(figsize=(10,4))
sns.barplot(x=data.columns, y=data.isnull().sum().values)
plt.xticks(rotation=45)
plt.ylabel('Number of Missing Values')
plt.title('Missing Values per Column')
plt.show()

# %%
data.loc[585, "Temperature"] = data[data["Signal Quality"] == "Good"]["Temperature"].mean()
data.loc[585, "Humidity"] = data[data["Signal Quality"] == "Good"]["Humidity"].mean()
data.loc[585, "Signal Quality"] = "Good"

# %%
data.isnull().sum()
# Out:
# Tx                        0
# Rx                        0
# Various Points            0
# SNR Receiver              0
# SNR Stages                0
# BER Receiver              0
# BER Environmental         0
# Modulation Format         0
# Modulation Depth          0
# Transmission Distance     0
# Distance Between          0
# Fiber Attenuation         0
# Splice Losses             0
# Optical Amplifier Gain    0
# PMD Coefficient           0
# PMD Compensation          0
# CD Coefficient            0
# CD Compensation           0
# Temperature               0
# Humidity                  0
# Signal Quality            0
# dtype: int64

# %%
plt.figure(figsize=(10,4))
sns.barplot(x=data.columns, y=data.isnull().sum().values)
plt.xticks(rotation=45)
plt.ylabel('Number of Missing Values')
plt.title('Missing Values per Column')
plt.show()

# %%
data.describe()
# Out:
#                Tx          Rx  Various Points  SNR Receiver  SNR Stages  \
# count  586.000000  586.000000      586.000000    586.000000  586.000000
# mean    11.152048   16.731229       13.126621     24.293515   22.755631
# std      0.996715    1.484506        0.307415      0.607918    0.603928
# min      9.200000   13.800000       12.400000     22.600000   21.100000
# 25%     10.300000   15.400000       12.900000     24.000000   22.400000
# 50%     11.050000   16.600000       13.200000     24.300000   22.800000
# 75%     12.100000   18.300000       13.400000     24.900000   23.300000
# max     12.900000   19.300000       13.800000     25.500000   24.000000
#
#        BER Receiver  BER Environmental  Modulation Depth  \
# count  5.860000e+02       5.860000e+02        586.000000
# mean   1.385495e-06       1.560751e-06          0.799659
# std    2.179418e-07       1.642245e-07          0.078663
# min    8.000000e-07       1.100000e-06          0.700000
# ...

# %% [markdown]
# **Key Summary Point**
# - Signal-to-Noise Ratio (SNR): Mean SNR for the receiver is 24.29 with a standard deviation of 0.61. SNR stages have a mean of 22.76 with a standard deviation of 0.60.
# - Bit Error Rate (BER): Mean receiver BER is very low at 1.39 * 10^-6 , with minimal variation (standard deviation of 2.18 * 10 ^-7)
# - Modulation Depth: The mean is 0.80, showing low variation (standard deviation of 0.08).
# - Transmission Distance: The average distance is 20.24 km with a standard deviation of 1.16 km.
# - Fiber Attenuation and Splice Losses: Average values are 0.10 dB/km and 0.20 dB, respectively.
# - Environmental Factors: Mean temperature is 25.24°C and humidity is 60.24%.

# %%
data[data["Signal Quality"] == "Poor"].describe()
# Out:
#               Tx         Rx  Various Points  SNR Receiver  SNR Stages  \
# count  47.000000  47.000000       47.000000     47.000000   47.000000
# mean    9.631915  14.404255       12.604255     22.974468   21.474468
# std     0.374808   0.400520        0.117875      0.184707    0.184707
# min     9.200000  13.800000       12.400000     22.600000   21.100000
# 25%     9.300000  14.000000       12.500000     22.800000   21.300000
# 50%     9.500000  14.300000       12.600000     23.000000   21.500000
# 75%    10.100000  14.800000       12.700000     23.200000   21.700000
# max    10.200000  14.900000       12.800000     23.200000   21.700000
#
#        BER Receiver  BER Environmental  Modulation Depth  \
# count  4.700000e+01       4.700000e+01         47.000000
# mean   8.893617e-07       1.189362e-06          0.797872
# std    8.903844e-08       8.903844e-08          0.057064
# min    8.000000e-07       1.100000e-06          0.700000
# ...

# %% [markdown]
# ## Summary
# The dataset appears to be quite consistent, with low variability across most of the variables, indicating stable conditions and high-quality signal transmission. The environmental factors like temperature and humidity also show minimal variability, which may contribute to the stability in transmission metrics. The low BER values further suggest that the signal quality is excellent across the dataset.

# %%
data[data["Signal Quality"] == "Good"].describe()
# Out:
#                Tx          Rx  Various Points  SNR Receiver  SNR Stages  \
# count  539.000000  539.000000      539.000000    539.000000  539.000000
# mean    11.284601   16.934137       13.172171     24.408534   22.867347
# std      0.921271    1.366849        0.275055      0.483406    0.487626
# min      9.700000   14.500000       12.600000     23.200000   21.700000
# 25%     10.500000   15.600000       12.900000     24.000000   22.400000
# 50%     11.100000   16.700000       13.200000     24.300000   22.800000
# 75%     12.100000   18.300000       13.400000     24.900000   23.300000
# max     12.900000   19.300000       13.800000     25.500000   24.000000
#
#        BER Receiver  BER Environmental  Modulation Depth  \
# count  5.390000e+02       5.390000e+02        539.000000
# mean   1.428757e-06       1.593135e-06          0.799814
# std    1.661071e-07       1.246900e-07          0.080311
# min    1.000000e-06       1.300000e-06          0.700000
# ...

# %% [markdown]
# ## Summary
# The dataset reflects a well-functioning optical transmission system with robust signal quality. Despite increased transmission distances and slightly higher losses, the system maintains low BER and stable SNR, indicating effective compensation mechanisms, such as amplification, are in place. Stable environmental conditions further support this performance, contributing to reliable and consistent data transmission across the system.

# %%
fig = plt.figure(figsize=(16, 7), dpi=200)
ax = fig.add_axes(141)
ax2 = fig.add_axes(142)
ax3 = fig.add_axes(143)
ax4 = fig.add_axes(144)
sns.countplot(data, x="Modulation Format", ax=ax)
sns.countplot(data, x="PMD Compensation", ax=ax2)
sns.countplot(data, x="CD Compensation", ax=ax3)
sns.countplot(data, x="Signal Quality", ax=ax4)
# Out:
# <Axes: xlabel='Signal Quality', ylabel='count'>

# %%
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(8, 6), dpi=300)
sns.kdeplot(data, multiple="stack", alpha=0.3)
# Out:
# <Axes: ylabel='Density'>

# %%
data = pd.get_dummies(data, drop_first=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586 entries, 0 to 585
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Tx                      586 non-null    float64
#  1   Rx                      586 non-null    float64
#  2   Various Points          586 non-null    float64
#  3   SNR Receiver            586 non-null    float64
#  4   SNR Stages              586 non-null    float64
#  5   BER Receiver            586 non-null    float64
#  6   BER Environmental       586 non-null    float64
#  7   Modulation Depth        586 non-null    float64
#  8   Transmission Distance   586 non-null    int64
#  9   Distance Between        586 non-null    int64
#  10  Fiber Attenuation       586 non-null    float64
#  11  Splice Losses           586 non-null    float64
#  12  Optical Amplifier Gain  586 non-null    int64
#  13  PMD Coefficient         586 non-null    float64
# ...

# %%
data["Modulation Format_FM"] = [0 if i else 1 for i in data["Modulation Format_FM"]]
data["Modulation Format_PM"] = [0 if i else 1 for i in data["Modulation Format_PM"]] 
data["Signal Quality_Poor"] = [0 if i else 1 for i in data["Signal Quality_Poor"]]

# %%
data.corr()
# Out:
#                               Tx        Rx  Various Points  SNR Receiver  \
# Tx                      1.000000  0.993050        0.902376      0.919636
# Rx                      0.993050  1.000000        0.928317      0.943934
# Various Points          0.902376  0.928317        1.000000      0.955862
# SNR Receiver            0.919636  0.943934        0.955862      1.000000
# SNR Stages              0.930158  0.950196        0.961359      0.995089
# BER Receiver            0.864061  0.877565        0.923768      0.961007
# BER Environmental       0.795431  0.804652        0.882119      0.902529
# Modulation Depth        0.251171  0.248210        0.273940      0.143295
# Transmission Distance   0.855647  0.867657        0.882945      0.944493
# Distance Between        0.855647  0.867657        0.882945      0.944493
# Fiber Attenuation       0.855647  0.867657        0.882945      0.944493
# Splice Losses           0.855647  0.867657        0.882945      0.944493
# ...

# %%
sns.heatmap(data.corr(),linewidths=0.1,fmt='0.1F')
# Out:
# <Axes: >

# %%
# Get all the Numerical feature 
num_features = [feature for feature in data.columns if data[feature].dtype != 'O']
print('Num of Numerical features:',len(num_features))
# Out:
# Num of Numerical features: 20

# %%
# Get all the Categorical feature 
cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']
print('Num of Categorical features:',len(cat_features))
# Out:
# Num of Categorical features: 0

# %%
# Discrete Feature 
discreate_features = [feature for feature in num_features if len(data[feature].unique())<=25]
print('Num of Descreate features:',len(discreate_features))
# Out:
# Num of Descreate features: 18

# %%
# Continuous Feature
con_features = [feature for feature in num_features if feature not in discreate_features]
print('Num of Continuous features:',len(con_features))
# Out:
# Num of Continuous features: 2

# %%
from sklearn.model_selection import train_test_split
# Separating the features and the target variable
X = data.drop("Signal Quality_Poor", axis=1)
y = data["Signal Quality_Poor"]
len(X), len(y)
# Out:
# (586, 586)

# %%
X.shape
# Out:
# (586, 19)

# %%
y.shape
# Out:
# (586,)

# %%
# Create column Transformer with3 types of transformers
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split

# Identifying categorical and numerical features
cat_features = X.select_dtypes(include='object').columns
num_features = X.select_dtypes(exclude='object').columns

# Defining transformers
numeric_transformer=StandardScaler()
oh_transformer = OneHotEncoder(drop='first')

# Creating the preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('OneHotEncoder', oh_transformer, cat_features),
        ('StandardScaler', numeric_transformer, num_features)
    ]
)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)

# %%
len(X_train)
# Out:
# 468

# %%
len(y_train)
# Out:
# 468

# %%
len(X_test)
# Out:
# 118

# %%
len(y_test)
# Out:
# 118

# %%
X_train.shape,X_test.shape
# Out:
# ((468, 19), (118, 19))

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('OneHotEncoder', OneHotEncoder(drop='first'),
#                                  Index([], dtype='object')),
#                                 ('StandardScaler', StandardScaler(),
#                                  Index(['Tx', 'Rx', 'Various Points', 'SNR Receiver', 'SNR Stages',
#        'BER Receiver', 'BER Environmental', 'Modulation Depth',
#        'Transmission Distance', 'Distance Between', 'Fiber Attenuation',
#        'Splice Losses', 'Optical Amplifier Gain', 'PMD Coefficient',
#        'CD Coefficient', 'Temperature', 'Humidity', 'Modulation Format_FM',
#        'Modulation Format_PM'],
#       dtype='object'))])

# %%
# applying the transformation in training (fit_transform)
X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()
param_grid = {"n_estimators": [32, 40, 48],
              "max_features": [7, 8, 9, 10],
              "bootstrap": [False],
              "oob_score": [False],
              "criterion": ['entropy', 'log_loss', 'gini']}

grid = GridSearchCV(model, param_grid)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [False],
#                          'criterion': ['entropy', 'log_loss', 'gini'],
#                          'max_features': [7, 8, 9, 10],
#                          'n_estimators': [32, 40, 48], 'oob_score': [False]})

# %%
grid.best_score_, grid.best_params_
# Out:
# (1.0,
#  {'bootstrap': False,
#   'criterion': 'entropy',
#   'max_features': 7,
#   'n_estimators': 32,
#   'oob_score': False})

# %%
y_preds = grid.predict(X_test)

# %%
print(classification_report(y_test, y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         8
#            1       1.00      1.00      1.00       110
#
#     accuracy                           1.00       118
#    macro avg       1.00      1.00      1.00       118
# weighted avg       1.00      1.00      1.00       118

# %%
list(data.columns)
# Out:
# ['Tx',
#  'Rx',
#  'Various Points',
#  'SNR Receiver',
#  'SNR Stages',
#  'BER Receiver',
#  'BER Environmental',
#  'Modulation Depth',
#  'Transmission Distance',
#  'Distance Between',
#  'Fiber Attenuation',
#  'Splice Losses',
#  'Optical Amplifier Gain',
#  'PMD Coefficient',
#  'CD Coefficient',
#  'Temperature',
#  'Humidity',
#  'Modulation Format_FM',
#  'Modulation Format_PM',
#  'Signal Quality_Poor']

# %%
plt.figure(figsize=(10, 7), dpi=200)
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, y_preds))
disp.plot()

# %%
fig = plt.figure(figsize=(10, 4), dpi=200)
ax = fig.add_axes(121)
ax2 = fig.add_axes(122)
sns.histplot(pd.DataFrame(y_preds), kde=True, element="step", ax=ax)
ax.set_title("Predicted Label")
sns.histplot(y_test, kde=True, element="step", ax=ax2)
ax2.set_title("True Label");

# %% [markdown]
# # Models Building

# %%
# !pip install xgboost

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %%
# Define models ( you can add no of option algo in between {    }    
models = {
    "Decision Tree": DecisionTreeClassifier(),
    "logistic Classifier": LogisticRegression(),
    "Random Forest": RandomForestClassifier(),
    "Adaboost":AdaBoostClassifier(),
    "Gradient Boost": GradientBoostingClassifier(),
    "XGBoost": XGBClassifier()
}

# Iterate over models
for name, model in models.items():
    # Fit the model
    model.fit(X_train, y_train)

    # Make predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # Training set performance
    model_train_accuracy = accuracy_score(y_train, y_train_pred)
    model_train_f1 = f1_score(y_train, y_train_pred, average='weighted')
    model_train_precision = precision_score(y_train, y_train_pred)
    model_train_recall = recall_score(y_train, y_train_pred)
    model_train_rocauc_score = roc_auc_score(y_train, y_train_pred)

    # Testing set performance 
    model_test_accuracy = accuracy_score(y_test, y_test_pred)
    model_test_f1 = f1_score(y_test, y_test_pred, average='weighted')
    model_test_precision = precision_score(y_test, y_test_pred)
    model_test_recall = recall_score(y_test, y_test_pred)
    model_test_rocauc_score = roc_auc_score(y_test, y_test_pred)

    # Print model name
    print(f"Model: {name}")

    # Print evaluation metrics for training set
    print("Training Set Performance:")
    print("Accuracy:", model_train_accuracy)
    print("F1 Score:", model_train_f1)
    print("Precision:", model_train_precision)
    print("Recall:", model_train_recall)
    print("ROC AUC Score:", model_train_rocauc_score)
    print("==============================================================")

    # Print evaluation metrics for testing set
    print("\nTesting Set Performance:")
    print("Accuracy:", model_test_accuracy)
    print("F1 Score:", model_test_f1)
    print("Precision:", model_test_precision)
    print("Recall:", model_test_recall)
    print("ROC AUC Score:", model_test_rocauc_score)
    print("==============================================================\n")
# Out:
# Model: Decision Tree
# Training Set Performance:
# Accuracy: 1.0
# F1 Score: 1.0
# Precision: 1.0
# Recall: 1.0
# ROC AUC Score: 1.0
# ...
#
# Testing Set Performance:
# Accuracy: 1.0
# F1 Score: 1.0
# Precision: 1.0
# Recall: 1.0
# ROC AUC Score: 1.0
# ...
#
# Model: logistic Classifier
# Training Set Performance:
# Accuracy: 1.0
# F1 Score: 1.0
# Precision: 1.0
# Recall: 1.0
# ROC AUC Score: 1.0
# ...
#
# Testing Set Performance:
# Accuracy: 1.0
# F1 Score: 1.0
# Precision: 1.0
# Recall: 1.0
# ROC AUC Score: 1.0
# ...
#
# Model: Random Forest
# Training Set Performance:
# Accuracy: 1.0
# F1 Score: 1.0
# Precision: 1.0
# Recall: 1.0
# ROC AUC Score: 1.0
# ...
#
# Testing Set Performance:
# Accuracy: 1.0
# F1 Score: 1.0
# Precision: 1.0
# Recall: 1.0
# ROC AUC Score: 1.0
# ...
#
# Model: Adaboost
# Training Set Performance:
# Accuracy: 1.0
# F1 Score: 1.0
# Precision: 1.0
# Recall: 1.0
# ROC AUC Score: 1.0
# ...
#
# Testing Set Performance:
# Accuracy: 1.0
# F1 Score: 1.0
# Precision: 1.0
# Recall: 1.0
# ROC AUC Score: 1.0
# ...

# %% [markdown]
# # Summary
# The results you’ve shared show that all the models—Decision Tree, Logistic Classifier, Random Forest, Adaboost, Gradient Boost, and XGBoost—achieved perfect scores across all performance metrics (Accuracy, F1 Score, Precision, Recall, and ROC AUC) on both the training and testing sets

# %% [markdown]
# ### Key Points:
# Perfect Scores Across the Board: Every model has achieved perfect performance metrics on both the training and testing sets, which is highly unusual.
#
# Possible Overfitting: Such results can indicate overfitting, especially if the models have memorized the training data rather than generalizing well. However, since the testing performance is also perfect, it might suggest either a very simple problem or a potential data leakage issue where the testing data might have been influenced by the training data.
#
# Model Performance Validation: To validate these results, consider cross-validation to ensure that the models perform consistently across different subsets of the data. Additionally, double-check the data preprocessing steps to ensure there's no data leakage.
#
# Re-examine the Dataset: Given the perfect scores, it's worth re-examining the dataset and the nature of the problem to confirm that such performance is reasonable and that the problem isn’t inherently trivial.
#
# Further Investigation: If these results hold up after cross-validation and data scrutiny, it suggests that the models are highly effective for the given task, but typically, it's rare to see such consistent perfect scores across all metrics and models.

# %% [markdown]
# # Hyperparameter Tunning

# %%
rf_params = { "max_depth":[5, 7,15,10, None],
             "max_features":[5,7,"auto",8],
             "min_samples_split":[2,8,15,20],
             "n_estimators":[100,200,500,1000]}


Xgb_params = {
    "learning_rate":[0.1,0.01],
    "max_depth":[5,8,12,20,30],
    "n_stimators":[100,200,300],
    "colsample_bytree":[0.3,0.4,0.5,0.8,1]
}

# %%
rf_params
# Out:
# {'max_depth': [5, 7, 15, 10, None],
#  'max_features': [5, 7, 'auto', 8],
#  'min_samples_split': [2, 8, 15, 20],
#  'n_estimators': [100, 200, 500, 1000]}

# %%
Xgb_params
# Out:
# {'learning_rate': [0.1, 0.01],
#  'max_depth': [5, 8, 12, 20, 30],
#  'n_stimators': [100, 200, 300],
#  'colsample_bytree': [0.3, 0.4, 0.5, 0.8, 1]}

# %%
randomcv_models = [
                ("RF",RandomForestClassifier(), rf_params),
    ("Xgb Boost",XGBClassifier(), Xgb_params)
    
]

# %%
randomcv_models
# Out:
# [('RF',
#   RandomForestClassifier(),
#   {'max_depth': [5, 7, 15, 10, None],
#    'max_features': [5, 7, 'auto', 8],
#    'min_samples_split': [2, 8, 15, 20],
#    'n_estimators': [100, 200, 500, 1000]}),
#  ('Xgb Boost',
#   XGBClassifier(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
# ...

# %%
from sklearn.model_selection import RandomizedSearchCV
model_param = {}
for name, model, params in randomcv_models:
    random =RandomizedSearchCV(estimator=model,
                               param_distributions=params,
                               n_iter=100,
                               cv=3,
                               verbose=2,
                               n_jobs=-1)

    random.fit(X_train, y_train)
    model_param[name] = random.best_params_

for model_name in model_param:
    print(f"--------------------Best Param for {model_name}---------------------------")
    print(model_param[model_name])
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# --------------------Best Param for RF---------------------------
# {'n_estimators': 1000, 'min_samples_split': 20, 'max_features': 5, 'max_depth': 15}
# --------------------Best Param for Xgb Boost---------------------------
# {'n_stimators': 300, 'max_depth': 30, 'learning_rate': 0.01, 'colsample_bytree': 0.3}

# %%
# Define models
models = {
    
    "Random Forest": RandomForestClassifier(n_estimators=200,min_samples_split=2,max_features=8,
                                           max_depth= None),
    "Xgb Boost ": XGBClassifier(n_stimators= 200, max_depth= 30, learning_rate= 0.1, colsample_bytree= 1)
}

# Iterate over models
for name, model in models.items():
    # Fit the model
    model.fit(X_train, y_train)

    # Make predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # Training set performance
    model_train_accuracy = accuracy_score(y_train, y_train_pred)
    model_train_f1 = f1_score(y_train, y_train_pred, average='weighted')
    model_train_precision = precision_score(y_train, y_train_pred)
    model_train_recall = recall_score(y_train, y_train_pred)
    model_train_rocauc_score = roc_auc_score(y_train, y_train_pred)

    # Testing set performance 
    model_test_accuracy = accuracy_score(y_test, y_test_pred)
    model_test_f1 = f1_score(y_test, y_test_pred, average='weighted')
    model_test_precision = precision_score(y_test, y_test_pred)
    model_test_recall = recall_score(y_test, y_test_pred)
    model_test_rocauc_score = roc_auc_score(y_test, y_test_pred)

    # Print model name
    print(f"Model: {name}")

    # Print evaluation metrics for training set
    print("Training Set Performance:")
    print("Accuracy:", model_train_accuracy)
    print("F1 Score:", model_train_f1)
    print("Precision:", model_train_precision)
    print("Recall:", model_train_recall)
    print("ROC AUC Score:", model_train_rocauc_score)
    print("==============================================================")

    # Print evaluation metrics for testing set
    print("\nTesting Set Performance:")
    print("Accuracy:", model_test_accuracy)
    print("F1 Score:", model_test_f1)
    print("Precision:", model_test_precision)
    print("Recall:", model_test_recall)
    print("ROC AUC Score:", model_test_rocauc_score)
    print("==============================================================\n")
# Out:
# Model: Random Forest
# Training Set Performance:
# Accuracy: 1.0
# F1 Score: 1.0
# Precision: 1.0
# Recall: 1.0
# ROC AUC Score: 1.0
# ...
#
# Testing Set Performance:
# Accuracy: 1.0
# F1 Score: 1.0
# Precision: 1.0
# Recall: 1.0
# ROC AUC Score: 1.0
# ...
#
# Model: Xgb Boost
# Training Set Performance:
# Accuracy: 1.0
# F1 Score: 1.0
# Precision: 1.0
# Recall: 1.0
# ROC AUC Score: 1.0
# ...
#
# Testing Set Performance:
# Accuracy: 1.0
# F1 Score: 1.0
# Precision: 1.0
# Recall: 1.0
# ROC AUC Score: 1.0
# ...

# %% [markdown]
# # ROC & AUC Curve Plot

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt
from xgboost import XGBClassifier

# Initialize and train the model
model = XGBClassifier(n_estimators=200, max_depth=30, learning_rate=0.1, colsample_bytree=1)
model.fit(X_train, y_train)

# Make predictions
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Get predicted probabilities for positive class
y_train_prob = model.predict_proba(X_train)[:, 1]
y_test_prob = model.predict_proba(X_test)[:, 1]

# Compute ROC curve and ROC AUC for training set
fpr_train, tpr_train, _ = roc_curve(y_train, y_train_prob)
roc_auc_train = roc_auc_score(y_train, y_train_prob)

# Compute ROC curve and ROC AUC for testing set
fpr_test, tpr_test, _ = roc_curve(y_test, y_test_prob)
roc_auc_test = roc_auc_score(y_test, y_test_prob)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr_train, tpr_train, color='blue', lw=2, label=f'Train ROC Curve (AUC = {roc_auc_train:.2f})')
plt.plot(fpr_test, tpr_test, color='red', lw=2, label=f'Test ROC Curve (AUC = {roc_auc_test:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--', lw=2, label='Random Guess')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
